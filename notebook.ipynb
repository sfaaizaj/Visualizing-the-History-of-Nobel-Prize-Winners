# %% [markdown]
# The Nobel Prize has been among the most prestigious international awards since 1901. Each year, awards are bestowed in chemistry, literature, physics, physiology or medicine, economics, and peace. In addition to the honor, prestige, and substantial prize money, the recipient also gets a gold medal with an image of Alfred Nobel (1833 - 1896), who established the prize.
#
# ![](Nobel_Prize.png)
#
# The Nobel Foundation has made a dataset available of all prize winners from the outset of the awards from 1901 to 2023. The dataset used in this project is from the Nobel Prize API and is available in the `nobel.csv` file in the `data` folder.
#
# In this project, you'll get a chance to explore and answer several questions related to this prizewinning data. And we encourage you then to explore further questions that you're interested in!

# %%
# Loading in required libraries
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
# Start coding here!
df=pd.read_csv('data/nobel.csv')
df1=pd.read_csv('data/nobel.csv')
df.head()
# Out:
#    year    category  ... death_city death_country
# 0  1901   Chemistry  ...     Berlin       Germany
# 1  1901  Literature  ...   Châtenay        France
# 2  1901    Medicine  ...    Marburg       Germany
# 3  1901       Peace  ...     Heiden   Switzerland
# 4  1901       Peace  ...      Paris        France
#
# [5 rows x 18 columns]

# %%
sns.countplot(x='sex',data=df)
plt.show()
top_gender='Male'
df1['birth_country'].value_counts()
top_country='United States Of America'

# %%
df['usa_born_winner'] = df['birth_country'] == 'United States of America'
df['decade'] = (np.floor(df['year'] / 10) * 10).astype(int)
prop_usa_winners = df.groupby('decade', as_index=False)['usa_born_winner'].mean()

# Identify the decade with the highest proportion of US-born winners
max_decade_usa = prop_usa_winners[prop_usa_winners['usa_born_winner'] == prop_usa_winners['usa_born_winner'].max()]['decade'].values[0]
prop_usa_winners
# Out:
#     decade  usa_born_winner
# 0     1900         0.017544
# 1     1910         0.075000
# 2     1920         0.074074
# 3     1930         0.250000
# 4     1940         0.302326
# 5     1950         0.291667
# 6     1960         0.265823
# 7     1970         0.317308
# 8     1980         0.319588
# 9     1990         0.403846
# 10    2000         0.422764
# 11    2010         0.314050
# 12    2020         0.360000

# %%
df[df['sex']=='Female'][['full_name','year','category']]
first_woman_name='Marie Curie, née Sklodowska'
first_woman_category='Physics'

# %%
count=df['full_name'].value_counts()
repeats=count[count > 1].index
repeat_list=list(repeats)
repeat_list
# Out:
# ['Comité international de la Croix Rouge (International Committee of the Red Cross)',
#  'Linus Carl Pauling',
#  'John Bardeen',
#  'Frederick Sanger',
#  'Marie Curie, née Sklodowska',
#  'Office of the United Nations High Commissioner for Refugees (UNHCR)']

# %%
a=df[df['sex']=='Female']
a.groupby('decade')['sex'].mean()
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# File /usr/local/lib/python3.8/dist-packages/pandas/core/groupby/groupby.py:1772, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1771 try:
# -> 1772     result = self.grouper._cython_operation(
#    1773         "aggregate",
#    1774         values,
#    1775         how,
#    1776         axis=data.ndim - 1,
#    1777         min_count=min_count,
#    1778         **kwargs,
#    1779     )
#    1780 except NotImplementedError:
#    1781     # generally if we have numeric_only=False
#    1782     # and non-applicable functions
#    1783     # try to python agg
#    1784     # TODO: shouldn't min_count matter?
#
# File /usr/local/lib/python3.8/dist-packages/pandas/core/groupby/ops.py:1039, in BaseGrouper._cython_operation(self, kind, values, how, axis, min_count, **kwargs)
#    1038 ngroups = self.ngroups
# -> 1039 return cy_op.cython_operation(
#    1040     values=values,
#    1041     axis=axis,
#    1042     min_count=min_count,
#    1043     comp_ids=ids,
#    1044     ngroups=ngroups,
#    1045     **kwargs,
#    1046 )
#
# File /usr/local/lib/python3.8/dist-packages/pandas/core/groupby/ops.py:708, in WrappedCythonOp.cython_operation(self, values, axis, min_count, comp_ids, ngroups, **kwargs)
#     700     return self._ea_wrap_cython_operation(
#     701         values,
#     702         min_count=min_count,
#    (...)
#     705         **kwargs,
#     706     )
# --> 708 return self._cython_op_ndim_compat(
#     709     values,
#     710     min_count=min_count,
#     711     ngroups=ngroups,
#     712     comp_ids=comp_ids,
#     713     mask=None,
#     714     **kwargs,
#     715 )
#
# File /usr/local/lib/python3.8/dist-packages/pandas/core/groupby/ops.py:512, in WrappedCythonOp._cython_op_ndim_compat(self, values, min_count, ngroups, comp_ids, mask, result_mask, **kwargs)
#     511     result_mask = result_mask[None, :]
# --> 512 res = self._call_cython_op(
#     513     values2d,
#     514     min_count=min_count,
#     515     ngroups=ngroups,
#     516     comp_ids=comp_ids,
#     517     mask=mask,
#     518     result_mask=result_mask,
#     519     **kwargs,
#     520 )
#     521 if res.shape[0] == 1:
#
# File /usr/local/lib/python3.8/dist-packages/pandas/core/groupby/ops.py:571, in WrappedCythonOp._call_cython_op(self, values, min_count, ngroups, comp_ids, mask, result_mask, **kwargs)
#     570 out_shape = self._get_output_shape(ngroups, values)
# --> 571 func = self._get_cython_function(self.kind, self.how, values.dtype, is_numeric)
#     572 values = self._get_cython_vals(values)
#
# File /usr/local/lib/python3.8/dist-packages/pandas/core/groupby/ops.py:192, in WrappedCythonOp._get_cython_function(cls, kind, how, dtype, is_numeric)
#     190 elif "object" not in f.__signatures__:
#     191     # raise NotImplementedError here rather than TypeError later
# --> 192     raise NotImplementedError(
#     193         f"function is not implemented for this dtype: "
#     194         f"[how->{how},dtype->{dtype_str}]"
#     195     )
#     196 return f
#
# NotImplementedError: function is not implemented for this dtype: [how->mean,dtype->object]
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# File /usr/local/lib/python3.8/dist-packages/pandas/core/nanops.py:1630, in _ensure_numeric(x)
#    1629 try:
# -> 1630     x = float(x)
#    1631 except (TypeError, ValueError):
#    1632     # e.g. "1+1j" or "foo"
#
# ValueError: could not convert string to float: 'FemaleFemaleFemale'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# File /usr/local/lib/python3.8/dist-packages/pandas/core/nanops.py:1634, in _ensure_numeric(x)
#    1633 try:
# -> 1634     x = complex(x)
#    1635 except ValueError as err:
#    1636     # e.g. "foo"
#
# ValueError: complex() arg is a malformed string
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[33], line 2
#       1 a=df[df['sex']=='Female']
# ----> 2 a.groupby('decade')['sex'].mean()
#
# File /usr/local/lib/python3.8/dist-packages/pandas/core/groupby/groupby.py:2161, in GroupBy.mean(self, numeric_only, engine, engine_kwargs)
#    2159     return self._numba_agg_general(sliding_mean, engine_kwargs)
#    2160 else:
# -> 2161     result = self._cython_agg_general(
#    2162         "mean",
#    2163         alt=lambda x: Series(x).mean(numeric_only=numeric_only_bool),
#    2164         numeric_only=numeric_only,
#    2165     )
#    2166     return result.__finalize__(self.obj, method="groupby")
#
# File /usr/local/lib/python3.8/dist-packages/pandas/core/groupby/groupby.py:1791, in GroupBy._cython_agg_general(self, how, alt, numeric_only, min_count, ignore_failures, **kwargs)
#    1787     return result
#    1789 # TypeError -> we may have an exception in trying to aggregate
#    1790 #  continue and exclude the block
# -> 1791 new_mgr = data.grouped_reduce(array_func, ignore_failures=ignore_failures)
#    1793 if not is_ser and len(new_mgr) < orig_len:
#    1794     warn_dropping_nuisance_columns_deprecated(type(self), how, numeric_only)
#
# File /usr/local/lib/python3.8/dist-packages/pandas/core/internals/base.py:199, in SingleDataManager.grouped_reduce(self, func, ignore_failures)
#     193 """
#     194 ignore_failures : bool, default False
#     195     Not used; for compatibility with ArrayManager/BlockManager.
#     196 """
#     198 arr = self.array
# --> 199 res = func(arr)
#     200 index = default_index(len(res))
#     202 mgr = type(self).from_array(res, index)
#
# File /usr/local/lib/python3.8/dist-packages/pandas/core/groupby/groupby.py:1785, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1772     result = self.grouper._cython_operation(
#    1773         "aggregate",
#    1774         values,
#    (...)
#    1778         **kwargs,
#    1779     )
#    1780 except NotImplementedError:
#    1781     # generally if we have numeric_only=False
#    1782     # and non-applicable functions
#    1783     # try to python agg
#    1784     # TODO: shouldn't min_count matter?
# -> 1785     result = self._agg_py_fallback(values, ndim=data.ndim, alt=alt)
#    1787 return result
#
# File /usr/local/lib/python3.8/dist-packages/pandas/core/groupby/groupby.py:1726, in GroupBy._agg_py_fallback(self, values, ndim, alt)
#    1721     ser = df.iloc[:, 0]
#    1723 # We do not get here with UDFs, so we know that our dtype
#    1724 #  should always be preserved by the implemented aggregations
#    1725 # TODO: Is this exactly right; see WrappedCythonOp get_result_dtype?
# -> 1726 res_values = self.grouper.agg_series(ser, alt, preserve_dtype=True)
#    1728 if isinstance(values, Categorical):
#    1729     # Because we only get here with known dtype-preserving
#    1730     #  reductions, we cast back to Categorical.
#    1731     # TODO: if we ever get "rank" working, exclude it here.
#    1732     res_values = type(values)._from_sequence(res_values, dtype=values.dtype)
#
# File /usr/local/lib/python3.8/dist-packages/pandas/core/groupby/ops.py:1081, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#    1078     preserve_dtype = True
#    1080 else:
# -> 1081     result = self._aggregate_series_pure_python(obj, func)
#    1083 npvalues = lib.maybe_convert_objects(result, try_float=False)
#    1084 if preserve_dtype:
#
# File /usr/local/lib/python3.8/dist-packages/pandas/core/groupby/ops.py:1104, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#    1101 splitter = get_splitter(obj, ids, ngroups, axis=0)
#    1103 for i, group in enumerate(splitter):
# -> 1104     res = func(group)
#    1105     res = libreduction.extract_result(res)
#    1107     if not initialized:
#    1108         # We only do this validation on the first iteration
#
# File /usr/local/lib/python3.8/dist-packages/pandas/core/groupby/groupby.py:2163, in GroupBy.mean.<locals>.<lambda>(x)
#    2159     return self._numba_agg_general(sliding_mean, engine_kwargs)
#    2160 else:
#    2161     result = self._cython_agg_general(
#    2162         "mean",
# -> 2163         alt=lambda x: Series(x).mean(numeric_only=numeric_only_bool),
#    2164         numeric_only=numeric_only,
#    2165     )
#    2166     return result.__finalize__(self.obj, method="groupby")
#
# File /usr/local/lib/python3.8/dist-packages/pandas/core/generic.py:11847, in NDFrame._add_numeric_operations.<locals>.mean(self, axis, skipna, level, numeric_only, **kwargs)
#   11829 @doc(
#   11830     _num_doc,
#   11831     desc="Return the mean of the values over the requested axis.",
#    (...)
#   11845     **kwargs,
#   11846 ):
# > 11847     return NDFrame.mean(self, axis, skipna, level, numeric_only, **kwargs)
#
# File /usr/local/lib/python3.8/dist-packages/pandas/core/generic.py:11401, in NDFrame.mean(self, axis, skipna, level, numeric_only, **kwargs)
#   11393 def mean(
#   11394     self,
#   11395     axis: Axis | None | lib.NoDefault = lib.no_default,
#    (...)
#   11399     **kwargs,
#   11400 ) -> Series | float:
# > 11401     return self._stat_function(
#   11402         "mean", nanops.nanmean, axis, skipna, level, numeric_only, **kwargs
#   11403     )
#
# File /usr/local/lib/python3.8/dist-packages/pandas/core/generic.py:11353, in NDFrame._stat_function(self, name, func, axis, skipna, level, numeric_only, **kwargs)
#   11343     warnings.warn(
#   11344         "Using the level keyword in DataFrame and Series aggregations is "
#   11345         "deprecated and will be removed in a future version. Use groupby "
#    (...)
#   11348         stacklevel=find_stack_level(),
#   11349     )
#   11350     return self._agg_by_level(
#   11351         name, axis=axis, level=level, skipna=skipna, numeric_only=numeric_only
#   11352     )
# > 11353 return self._reduce(
#   11354     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   11355 )
#
# File /usr/local/lib/python3.8/dist-packages/pandas/core/series.py:4816, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    4812     raise NotImplementedError(
#    4813         f"Series.{name} does not implement {kwd_name}."
#    4814     )
#    4815 with np.errstate(all="ignore"):
# -> 4816     return op(delegate, skipna=skipna, **kwds)
#
# File /usr/local/lib/python3.8/dist-packages/pandas/core/nanops.py:93, in disallow.__call__.<locals>._f(*args, **kwargs)
#      91 try:
#      92     with np.errstate(invalid="ignore"):
# ---> 93         return f(*args, **kwargs)
#      94 except ValueError as e:
#      95     # we want to transform an object array
#      96     # ValueError message to the more typical TypeError
#      97     # e.g. this is normally a disallowed function on
#      98     # object arrays that contain strings
#      99     if is_object_dtype(args[0]):
#
# File /usr/local/lib/python3.8/dist-packages/pandas/core/nanops.py:155, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     153         result = alt(values, axis=axis, skipna=skipna, **kwds)
#     154 else:
# --> 155     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     157 return result
#
# File /usr/local/lib/python3.8/dist-packages/pandas/core/nanops.py:418, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
#     415 if datetimelike and mask is None:
#     416     mask = isna(values)
# --> 418 result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     420 if datetimelike:
#     421     result = _wrap_results(result, orig_values.dtype, fill_value=iNaT)
#
# File /usr/local/lib/python3.8/dist-packages/pandas/core/nanops.py:706, in nanmean(values, axis, skipna, mask)
#     703     dtype_count = dtype
#     705 count = _get_counts(values.shape, mask, axis, dtype=dtype_count)
# --> 706 the_sum = _ensure_numeric(values.sum(axis, dtype=dtype_sum))
#     708 if axis is not None and getattr(the_sum, "ndim", False):
#     709     count = cast(np.ndarray, count)
#
# File /usr/local/lib/python3.8/dist-packages/pandas/core/nanops.py:1637, in _ensure_numeric(x)
#    1634             x = complex(x)
#    1635         except ValueError as err:
#    1636             # e.g. "foo"
# -> 1637             raise TypeError(f"Could not convert {x} to numeric") from err
#    1638 return x
#
# TypeError: Could not convert FemaleFemaleFemale to numeric

# %%
# Out:
#   Cell In[32], line 1
#     ._dc_cell_type = 'visualization'
#     ^
# SyntaxError: invalid syntax
